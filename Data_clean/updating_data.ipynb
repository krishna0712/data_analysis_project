# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../sales_data.csv')

# %%
df.head()
# Out:
#    Order ID                   Product  Quantity  Price Each  \
# 0    150502                    iPhone       1.0      700.00
# 1    150503     AA Batteries (4-pack)       1.0        3.84
# 2    150504    27in 4K Gaming Monitor       1.0      389.99
# 3    150505  Lightning Charging Cable       1.0       14.95
# 4    150506     AA Batteries (4-pack)       2.0        3.84
#
#                   Date                     Purchase Address  Month  Revenue  \
# 0  2019-02-18 01:35:00    866 Spruce St, Portland, ME 04101      2   700.00
# 1  2019-02-13 07:24:00  18 13th St, San Francisco, CA 94016      2     3.84
# 2  2019-02-18 09:46:00   52 6th St, New York City, NY 10001      2   389.99
# 3  2019-02-02 16:47:00     129 Cherry St, Atlanta, GA 30301      2    14.95
# 4  2019-02-28 20:32:00    548 Lincoln St, Seattle, WA 98101      2     7.68
#
#    Year Month_Name Year_Month
# 0  2019   February    2019-02
# 1  2019   February    2019-02
# 2  2019   February    2019-02
# ...

# %%
df1 = df.copy()

# %%
df1 = df1["Year_Month"] != "2020-01"

# %%
df1.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Year_Month, dtype: bool

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#    Order ID                   Product  Quantity  Price Each  \
# 0    150502                    iPhone       1.0      700.00
# 1    150503     AA Batteries (4-pack)       1.0        3.84
# 2    150504    27in 4K Gaming Monitor       1.0      389.99
# 3    150505  Lightning Charging Cable       1.0       14.95
# 4    150506     AA Batteries (4-pack)       2.0        3.84
#
#                   Date                     Purchase Address  Month  Revenue  \
# 0  2019-02-18 01:35:00    866 Spruce St, Portland, ME 04101      2   700.00
# 1  2019-02-13 07:24:00  18 13th St, San Francisco, CA 94016      2     3.84
# 2  2019-02-18 09:46:00   52 6th St, New York City, NY 10001      2   389.99
# 3  2019-02-02 16:47:00     129 Cherry St, Atlanta, GA 30301      2    14.95
# 4  2019-02-28 20:32:00    548 Lincoln St, Seattle, WA 98101      2     7.68
#
#    Year Month_Name Year_Month
# 0  2019   February    2019-02
# 1  2019   February    2019-02
# 2  2019   February    2019-02
# ...

# %%
df2 = df2[~((df2["Year"] == 2020) & (df2["Month"] == 1))]

# %%
df2[df2["Year_Month"] == "2020-01"]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity, Price Each, Date, Purchase Address, Month, Revenue, Year, Month_Name, Year_Month]
# Index: []

# %%
df = df2

# %%
df[df["Year_Month"] == "2020-01"]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity, Price Each, Date, Purchase Address, Month, Revenue, Year, Month_Name, Year_Month]
# Index: []

# %%
df.head()
# Out:
#    Order ID                   Product  Quantity  Price Each  \
# 0    150502                    iPhone       1.0      700.00
# 1    150503     AA Batteries (4-pack)       1.0        3.84
# 2    150504    27in 4K Gaming Monitor       1.0      389.99
# 3    150505  Lightning Charging Cable       1.0       14.95
# 4    150506     AA Batteries (4-pack)       2.0        3.84
#
#                   Date                     Purchase Address  Month  Revenue  \
# 0  2019-02-18 01:35:00    866 Spruce St, Portland, ME 04101      2   700.00
# 1  2019-02-13 07:24:00  18 13th St, San Francisco, CA 94016      2     3.84
# 2  2019-02-18 09:46:00   52 6th St, New York City, NY 10001      2   389.99
# 3  2019-02-02 16:47:00     129 Cherry St, Atlanta, GA 30301      2    14.95
# 4  2019-02-28 20:32:00    548 Lincoln St, Seattle, WA 98101      2     7.68
#
#    Year Month_Name Year_Month
# 0  2019   February    2019-02
# 1  2019   February    2019-02
# 2  2019   February    2019-02
# ...

# %%
df.to_csv('../sales_data.csv', index=False)
